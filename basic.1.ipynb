# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=15
c=5
print(a+b)
# Out:
# 25

# %%
print("samyak")
print("22")
print("Male")
# Out:
# samyak
# 22
# Male

# %%
print(21,"lekhana",22,"samyak,")
# Out:
# 21 lekhana 22 samyak,

# %%
print("name=","samyak")
print("age=",21)
print("gender=","male")
print("yog=",2026)
# Out:
# name= samyak
# age= 21
# gender= male
# yog= 2026
